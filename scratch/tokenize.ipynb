# %%
# get num tokens for Zarf docs

import os
import tiktoken
from pathlib import Path

def count_tokens(text, model="gpt-4o-mini"):
    """Count the number of tokens in the given text."""
    encoding = tiktoken.encoding_for_model(model)
    return len(encoding.encode(text))

def process_file(file_path, model="gpt-4o-mini"):
    """Process a single file and return its token count."""
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
    token_count = count_tokens(content, model)
    return token_count

def process_folder(folder_path, model="gpt-4o-mini"):
    """Process all .md and .mdx files in the given folder and its subfolders."""
    total_tokens = 0
    file_counts = {}

    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.endswith(('.md', '.mdx')):
                file_path = Path(root) / file
                token_count = process_file(file_path, model)
                total_tokens += token_count
                file_counts[str(file_path)] = token_count

    return total_tokens, file_counts

folder_path = "../zarf/site/src/content/docs"
model = "gpt-4o-mini"

total_tokens, file_counts = process_folder(folder_path, model)

print(f"\nTotal tokens across all files: {total_tokens}")
print("\nToken count for each file:")
for file, count in sorted(file_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"{file}: {count} tokens")
# Out:
# Total tokens across all files: 86761
#
# Token count for each file:
# ../zarf/site/src/content/docs/ref/init-package.mdx: 4219 tokens
# ../zarf/site/src/content/docs/ref/components.mdx: 3986 tokens
# ../zarf/site/src/content/docs/tutorials/0-creating-a-zarf-package.mdx: 2929 tokens
# ../zarf/site/src/content/docs/ref/actions.mdx: 2623 tokens
# ../zarf/site/src/content/docs/contribute/style-guide.mdx: 2575 tokens
# ../zarf/site/src/content/docs/tutorials/5-big-bang.mdx: 2096 tokens
# ../zarf/site/src/content/docs/ref/deploy.mdx: 2031 tokens
# ../zarf/site/src/content/docs/ref/packages.mdx: 1663 tokens
# ../zarf/site/src/content/docs/ref/values.mdx: 1630 tokens
# ../zarf/site/src/content/docs/tutorials/6-publish-and-deploy.mdx: 1629 tokens
# ../zarf/site/src/content/docs/faq.mdx: 1582 tokens
# ../zarf/site/src/content/docs/tutorials/7-custom-init-packages.mdx: 1545 tokens
# ../zarf/site/src/content/docs/contribute/testing.mdx: 1477 tokens
# ../zarf/site/src/content/docs/tutorials/2-deploying-zarf-packages.mdx: 1454 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_yq_eval-all.md: 1333 tokens
# ../zarf/site/src/content/docs/ref/deployment-ui.mdx: 1332 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_yq.md: 1305 tokens
# ../zarf/site/src/content/docs/getting-started/install.mdx: 1293 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_yq_eval.md: 1288 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_yq_completion.md: 1263 tokens
# ../zarf/site/src/content/docs/tutorials/3-deploy-a-retro-arcade.mdx: 1244 tokens
# ../zarf/site/src/content/docs/commands/zarf_init.md: 1200 tokens
# ../zarf/site/src/content/docs/roadmap.mdx: 1199 tokens
# ../zarf/site/src/content/docs/ref/sboms.mdx: 1107 tokens
# ../zarf/site/src/content/docs/ref/create.mdx: 1003 tokens
# ../zarf/site/src/content/docs/index.mdx: 980 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_update-creds.md: 951 tokens
# ../zarf/site/src/content/docs/ref/dev.mdx: 944 tokens
# ../zarf/site/src/content/docs/commands/zarf_package_mirror-resources.md: 924 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_helm_dependency.md: 892 tokens
# ../zarf/site/src/content/docs/tutorials/8-resource-adoption.mdx: 866 tokens
# ../zarf/site/src/content/docs/ref/config-files.mdx: 828 tokens
# ../zarf/site/src/content/docs/contribute/nerd-notes.mdx: 791 tokens
# ../zarf/site/src/content/docs/getting-started/understanding.mdx: 753 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools.md: 753 tokens
# ../zarf/site/src/content/docs/commands/zarf_package_create.md: 733 tokens
# ../zarf/site/src/content/docs/ref/index.mdx: 727 tokens
# ../zarf/site/src/content/docs/commands/zarf_connect.md: 705 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_wait-for.md: 704 tokens
# ../zarf/site/src/content/docs/commands/zarf_package_deploy.md: 659 tokens
# ../zarf/site/src/content/docs/commands/zarf_dev_deploy.md: 646 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_helm_repo_add.md: 628 tokens
# ../zarf/site/src/content/docs/tutorials/9-package-create-differential.mdx: 619 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_sbom.md: 616 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_helm_dependency_update.md: 612 tokens
# ../zarf/site/src/content/docs/tutorials/4-creating-a-k8s-cluster-with-zarf.mdx: 611 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_helm_repo.md: 610 tokens
# ../zarf/site/src/content/docs/commands/zarf_package.md: 584 tokens
# ../zarf/site/src/content/docs/commands/zarf_dev_find-images.md: 578 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_helm_repo_index.md: 574 tokens
# ../zarf/site/src/content/docs/tutorials/index.mdx: 565 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_helm_dependency_build.md: 565 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_helm_repo_update.md: 552 tokens
# ../zarf/site/src/content/docs/commands/zarf_dev.md: 536 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_monitor.md: 528 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_helm.md: 520 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_helm_dependency_list.md: 506 tokens
# ../zarf/site/src/content/docs/commands/zarf_package_pull.md: 501 tokens
# ../zarf/site/src/content/docs/commands/zarf.md: 496 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_sbom_scan.md: 492 tokens
# ../zarf/site/src/content/docs/commands/zarf_destroy.md: 491 tokens
# ../zarf/site/src/content/docs/getting-started/index.mdx: 488 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_sbom_attest.md: 481 tokens
# ../zarf/site/src/content/docs/tutorials/1-initializing-a-k8s-cluster.mdx: 477 tokens
# ../zarf/site/src/content/docs/commands/zarf_package_publish.md: 473 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_helm_repo_list.md: 470 tokens
# ../zarf/site/src/content/docs/commands/zarf_completion_zsh.md: 466 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_registry.md: 464 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_helm_repo_remove.md: 455 tokens
# ../zarf/site/src/content/docs/ref/tools.mdx: 449 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_helm_version.md: 439 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_get-creds.md: 437 tokens
# ../zarf/site/src/content/docs/commands/zarf_completion_bash.md: 436 tokens
# ../zarf/site/src/content/docs/commands/zarf_package_inspect.md: 435 tokens
# ../zarf/site/src/content/docs/commands/zarf_package_remove.md: 434 tokens
# ../zarf/site/src/content/docs/commands/zarf_dev_generate.md: 430 tokens
# ../zarf/site/src/content/docs/commands/zarf_completion.md: 426 tokens
# ../zarf/site/src/content/docs/commands/zarf_dev_generate-config.md: 409 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_archiver.md: 396 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_registry_pull.md: 392 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_registry_push.md: 388 tokens
# ../zarf/site/src/content/docs/commands/zarf_dev_lint.md: 388 tokens
# ../zarf/site/src/content/docs/commands/zarf_completion_fish.md: 387 tokens
# ../zarf/site/src/content/docs/commands/zarf_dev_patch-git.md: 378 tokens
# ../zarf/site/src/content/docs/commands/zarf_completion_powershell.md: 378 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_registry_delete.md: 367 tokens
# ../zarf/site/src/content/docs/commands/zarf_package_list.md: 356 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_sbom_convert.md: 355 tokens
# ../zarf/site/src/content/docs/commands/zarf_dev_sha256sum.md: 349 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_archiver_decompress.md: 344 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_registry_digest.md: 342 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_registry_ls.md: 338 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_gen-pki.md: 335 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_download-init.md: 331 tokens
# ../zarf/site/src/content/docs/commands/zarf_version.md: 327 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_archiver_compress.md: 326 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_gen-key.md: 314 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_clear-cache.md: 313 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_archiver_version.md: 312 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_registry_copy.md: 299 tokens
# ../zarf/site/src/content/docs/commands/zarf_connect_list.md: 298 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_registry_version.md: 279 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_registry_catalog.md: 276 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_registry_login.md: 252 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_registry_prune.md: 241 tokens
# ../zarf/site/src/content/docs/ref/github-action.mdx: 228 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_sbom_login.md: 224 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_sbom_version.md: 206 tokens
# ../zarf/site/src/content/docs/commands/zarf_tools_kubectl.md: 134 tokens
# ../zarf/site/src/content/docs/support.mdx: 125 tokens
# ../zarf/site/src/content/docs/contribute/contributor-guide.mdx: 68 tokens

# %%
# get num tokens for event and log data

import os
import tiktoken
from pathlib import Path

def count_tokens(text, model="gpt-4"):
    """Count the number of tokens in the given text."""
    encoding = tiktoken.encoding_for_model(model)
    return len(encoding.encode(text))

def process_file(file_path, model="gpt-4o-mini"):
    """Process a single file and return its token count and content."""
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
    token_count = count_tokens(content, model)
    return token_count, content

def process_files(log_file, event_file, model="gpt-4o-mini"):
    """Process the log and event files."""
    log_tokens, log_content = process_file(log_file, model)
    event_tokens, event_content = process_file(event_file, model)
    total_tokens = log_tokens + event_tokens
    return total_tokens, log_tokens, event_tokens, log_content, event_content

log_file = "core-deployed-logs-2.txt"
event_file = "core-deployed-events-2.txt"
model = "gpt-4o-mini"

total_tokens, log_tokens, event_tokens, log_content, event_content = process_files(log_file, event_file, model)

print(f"\nTotal tokens: {total_tokens}")
print(f"Log file tokens: {log_tokens}")
print(f"Event file tokens: {event_tokens}")
# Out:
# Total tokens: 105715
# Log file tokens: 68183
# Event file tokens: 37532

# %%
# tokens for uds docs

import os
import tiktoken
from pathlib import Path

def count_tokens(text, model="gpt-4o-mini"):
    """Count the number of tokens in the given text."""
    encoding = tiktoken.encoding_for_model(model)
    return len(encoding.encode(text))

def process_file(file_path, model="gpt-4o-mini"):
    """Process a single file and return its token count."""
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
    token_count = count_tokens(content, model)
    return token_count

def process_folder(folder_path, model="gpt-4o-mini"):
    """Process all .md and .mdx files in the given folder and its subfolders."""
    total_tokens = 0
    file_counts = {}

    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.endswith(('.md', '.mdx')):
                file_path = Path(root) / file
                token_count = process_file(file_path, model)
                total_tokens += token_count
                file_counts[str(file_path)] = token_count

    return total_tokens, file_counts

folder_path = "../uds/uds-core/docs/"
operator_docs_folder = "../uds/uds-core/src/pepr"
model = "gpt-4o-mini"

docs_tokens, docs_file_counts = process_folder(folder_path, model)
operator_docs_tokens, operator_file_counts = process_folder(operator_docs_folder, model)
file_counts = docs_file_counts | operator_file_counts

print(f"\nTotal tokens across all files: {docs_tokens + operator_docs_tokens}")
print("\nToken count for each file:")
for file, count in sorted(file_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"{file}: {count} tokens")
# Out:
# Total tokens across all files: 11379
#
# Token count for each file:
# ../uds/uds-core/src/pepr/policies/README.md: 2942 tokens
# ../uds/uds-core/src/pepr/operator/README.md: 1952 tokens
# ../uds/uds-core/docs/configuration/uds-operator.md: 1919 tokens
# ../uds/uds-core/docs/deployment/uds-deploy.md: 1218 tokens
# ../uds/uds-core/docs/configuration/uds-monitoring-metrics.md: 993 tokens
# ../uds/uds-core/docs/application-baseline.md: 603 tokens
# ../uds/uds-core/docs/configuration/uds-user-groups.md: 576 tokens
# ../uds/uds-core/docs/_index.md: 409 tokens
# ../uds/uds-core/docs/configuration/uds-configure-policy-exemptions.md: 273 tokens
# ../uds/uds-core/docs/deployment/distribution-support.md: 266 tokens
# ../uds/uds-core/src/pepr/README.md: 99 tokens
# ../uds/uds-core/docs/development/uds-development-maintenance.md: 50 tokens
# ../uds/uds-core/src/pepr/istio/README.md: 24 tokens
# ../uds/uds-core/docs/deployment/_index.md: 19 tokens
# ../uds/uds-core/docs/configuration/_index.md: 18 tokens
# ../uds/uds-core/docs/development/_index.md: 18 tokens
